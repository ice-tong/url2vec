# %%
import tensorflow as tf

# %%
import os
import urllib.request as request

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
import zipfile

# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

words = read_data(filename)
print('Data size', len(words))
# Out:
# Data size 17005207

# %%
import collections

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words, vocabulary_size):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words, vocabulary_size)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5237, 3082, 12, 6, 195, 2, 3137, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
import numpy as np
import random

# Step 3: Function to generate a training batch for the skip-gram model.
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3082 originated -> 5237 anarchism
# 3082 originated -> 12 as
# 12 as -> 3082 originated
# 12 as -> 6 a
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of

# %%
# Step 4: Build and train a skip-gram model.
import math

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
from six.moves import xrange

num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print("Initialized")

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print("Average loss at step ", step, ": ", average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = "Nearest to %s:" % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  277.81552124
# Nearest to are: overseas, bernoulli, grasping, springboard, relieving, ayres, emirate, flotilla,
# Nearest to of: occupations, internecine, conformation, narrowly, sails, plebiscite, build, sic,
# Nearest to s: scarp, pots, inspected, advisory, heresiologists, erie, benefited, fjords,
# Nearest to nine: perched, untold, avalanches, methodism, benghazi, hypocrites, protectionism, candid,
# Nearest to by: ksc, vaux, hues, rheumatoid, neoconservative, microbiologist, embryos, kasner,
# Nearest to at: glendale, formatting, interdisciplinary, adorno, poorly, sedgwick, tallinn, ursus,
# Nearest to state: immortals, confederations, bound, could, markkaa, sein, sets, barnes,
# Nearest to and: idealism, rigid, petn, celia, cute, proximal, streamline, dedication,
# Nearest to one: challenge, vague, ilium, duquette, rotate, siam, narcotics, topical,
# Nearest to been: earths, promises, fielding, ij, comptroller, wilmington, evaluate, playlists,
# Nearest to or: replenishment, pleasures, subtlety, sadness, discredited, smoking, egyptology, spitting,
# Nearest to used: tai, clog, dickson, faulty, mitt, recover, needham, draconis,
# Nearest to his: stated, position, flourish, chojn, genres, aelius, exuberant, siberia,
# Nearest to united: usury, ingesting, aki, dragoons, festivals, add, browne, erasmus,
# Nearest to as: scott, aai, explores, whois, braque, librarian, pork, maids,
# Nearest to history: prozac, asf, tumor, cramped, implants, milieu, footballer, dues,
# Average loss at step  2000 :  113.769561504
# Average loss at step  4000 :  52.0875262902
# Average loss at step  6000 :  33.5504813931
# Average loss at step  8000 :  23.5284109592
# Average loss at step  10000 :  17.8446276934
# Nearest to are: is, overseas, by, and, have, was, secure, battlefield,
# Nearest to of: and, in, for, with, from, the, to, by,
# Nearest to s: bio, and, psi, of, springfield, solf, nixon, microscopy,
# Nearest to nine: zero, eight, vs, phi, one, six, seven, bckgr,
# Nearest to by: and, in, is, of, UNK, ksc, lnot, solf,
# Nearest to at: in, pushes, implementation, jinx, sedgwick, and, tar, with,
# Nearest to state: bound, sets, verse, pregnancy, capacity, two, revealed, could,
# Nearest to and: in, of, UNK, or, by, for, the, as,
# Nearest to one: zero, two, bckgr, nine, vs, three, archie, canaris,
# Nearest to been: ij, arctic, breathing, prevents, named, closer, agave, along,
# Nearest to or: and, UNK, of, bckgr, publicity, sulfur, vs, agave,
# Nearest to used: tai, recover, wife, dense, williams, texas, faulty, mini,
# Nearest to his: the, position, their, extreme, dean, psi, each, minutes,
# Nearest to united: mathbf, owner, ingesting, boroughs, route, garden, festivals, aka,
# Nearest to as: and, in, on, phi, vs, explores, scott, coke,
# Nearest to history: footballer, exist, festival, majority, areas, wyatt, rotate, glaciers,
# Average loss at step  12000 :  14.1372761312
# Average loss at step  14000 :  11.8365493282
# Average loss at step  16000 :  10.1306483876
# Average loss at step  18000 :  8.37514309013
# Average loss at step  20000 :  7.92887224305
# Nearest to are: is, were, was, and, overseas, have, by, operatorname,
# Nearest to of: and, in, for, circ, from, nine, operatorname, zero,
# Nearest to s: and, the, zero, his, bio, operatorname, of, dasyprocta,
# Nearest to nine: eight, six, seven, zero, four, five, three, agouti,
# Nearest to by: in, was, and, with, for, is, dasyprocta, UNK,
# Nearest to at: in, and, circ, from, pushes, with, on, of,
# Nearest to state: aristocratic, agouti, wished, dasyprocta, operatorname, capacity, perceptual, bound,
# Nearest to and: or, of, circ, in, gum, with, operatorname, phi,
# Nearest to one: two, operatorname, nine, agouti, three, dasyprocta, eight, six,
# Nearest to been: ij, was, be, earths, breathing, prevents, homestead, dictatorships,
# Nearest to or: and, circ, eight, phi, seven, nine, three, UNK,
# Nearest to used: tai, williams, designed, mini, recover, able, dddddd, texas,
# Nearest to his: the, their, s, its, circ, agouti, extreme, dean,
# Nearest to united: dasyprocta, owner, agouti, operatorname, ingesting, mathbf, aka, festivals,
# Nearest to as: and, in, is, with, satirical, on, coke, hence,
# Nearest to history: operatorname, agouti, footballer, exist, asf, dasyprocta, festival, its,
# Average loss at step  22000 :  7.18551180553
# Average loss at step  24000 :  6.82748412204
# Average loss at step  26000 :  6.68449617749
# Average loss at step  28000 :  6.38917267764
# Average loss at step  30000 :  5.93414372993
# Nearest to are: were, is, have, was, by, seven, overseas, operatorname,
# Nearest to of: and, in, for, trinomial, nine, circ, eight, mishnayot,
# Nearest to s: and, zero, the, his, two, dasyprocta, circ, bio,
# Nearest to nine: eight, seven, six, five, four, zero, three, agouti,
# Nearest to by: with, in, was, for, from, be, while, dasyprocta,
# Nearest to at: in, and, from, with, sponsors, during, on, circ,
# Nearest to state: aristocratic, wished, discard, agouti, dasyprocta, capacity, operatorname, bound,
# Nearest to and: or, circ, gum, with, phi, operatorname, one, in,
# Nearest to one: two, operatorname, four, seven, eight, dasyprocta, agouti, three,
# Nearest to been: be, was, by, ij, breathing, dictatorships, min, marcellus,
# Nearest to or: and, phi, circ, bckgr, acacia, seven, eight, agouti,
# Nearest to used: tai, designed, able, mini, dddddd, williams, recover, agouti,
# Nearest to his: their, the, its, s, her, dean, circ, agouti,
# Nearest to united: owner, dasyprocta, ingesting, agouti, akh, venue, amalthea, operatorname,
# Nearest to as: and, primigenius, coke, is, satirical, vs, phi, varphi,
# Nearest to history: operatorname, agouti, prozac, footballer, dasyprocta, exist, its, majority,
# Average loss at step  32000 :  5.9590888955
# Average loss at step  34000 :  5.72730009115
# Average loss at step  36000 :  5.78247290039
# Average loss at step  38000 :  5.49895690989
# Average loss at step  40000 :  5.25822898257
# Nearest to are: were, is, have, was, zero, operatorname, eight, annihilated,
# Nearest to of: in, for, circ, and, zero, trinomial, agouti, operatorname,
# Nearest to s: zero, his, and, dasyprocta, bio, two, circ, operatorname,
# Nearest to nine: eight, seven, six, zero, five, four, three, agouti,
# Nearest to by: was, in, be, with, were, dasyprocta, lnot, while,
# Nearest to at: in, akimbo, during, sponsors, from, on, circ, and,
# Nearest to state: aristocratic, discard, wished, operatorname, dasyprocta, agouti, perceptual, capacity,
# Nearest to and: or, in, but, circ, with, which, zero, vs,
# Nearest to one: two, operatorname, three, four, seven, eight, six, agouti,
# Nearest to been: be, was, by, dictatorships, marcellus, breathing, ij, were,
# Nearest to or: and, phi, zero, circ, acacia, stitch, bckgr, agouti,
# Nearest to used: designed, bryozoans, able, dddddd, tai, agouti, mini, williams,
# Nearest to his: their, its, the, her, dean, s, agouti, dasyprocta,
# Nearest to united: owner, dasyprocta, akimbo, ingesting, agouti, operatorname, amalthea, akh,
# Nearest to as: and, primigenius, coke, varphi, four, swaziland, phi, satirical,
# Nearest to history: operatorname, agouti, dasyprocta, footballer, prozac, its, majority, exist,
# Average loss at step  42000 :  5.3666929723
# Average loss at step  44000 :  5.25396063292
# Average loss at step  46000 :  5.25257640207
# Average loss at step  48000 :  5.24816321647
# Average loss at step  50000 :  4.99544652033
# Nearest to are: were, is, have, was, be, eight, krantz, annihilated,
# Nearest to of: in, for, circ, trinomial, akimbo, agouti, cio, eight,
# Nearest to s: his, and, zero, bio, dasyprocta, of, operatorname, hispanic,
# Nearest to nine: eight, six, seven, zero, five, three, four, agouti,
# Nearest to by: was, be, in, were, while, with, for, dasyprocta,
# Nearest to at: in, akimbo, during, from, on, sponsors, circ, six,
# Nearest to state: aristocratic, wished, discard, capacity, operatorname, dasyprocta, language, agouti,
# Nearest to and: or, but, four, operatorname, seven, eight, six, circ,
# Nearest to one: two, four, eight, six, five, operatorname, three, seven,
# Nearest to been: be, was, by, become, were, dedicating, dictatorships, marcellus,
# Nearest to or: and, phi, three, seven, eight, circ, stitch, four,
# Nearest to used: designed, bryozoans, able, dddddd, airtight, agouti, tai, seen,
# Nearest to his: their, its, the, her, s, dean, agouti, dasyprocta,
# Nearest to united: owner, dasyprocta, ingesting, akimbo, balcony, agouti, aka, amalthea,
# Nearest to as: coke, primigenius, and, agouti, when, satirical, in, by,
# Nearest to history: operatorname, agouti, roshan, dasyprocta, footballer, prozac, majority, its,
# Average loss at step  52000 :  5.04876024985
# Average loss at step  54000 :  5.17961683857
# Average loss at step  56000 :  5.03970304704
# Average loss at step  58000 :  5.04084424984
# Average loss at step  60000 :  4.96325808537
# Nearest to are: were, is, have, microsite, do, be, was, annihilated,
# Nearest to of: in, and, nine, trinomial, pulau, circ, for, cio,
# Nearest to s: and, zero, his, dasyprocta, operatorname, circ, hispanic, uc,
# Nearest to nine: eight, six, seven, four, five, zero, ursus, agouti,
# Nearest to by: was, be, eight, while, as, dasyprocta, pulau, with,
# Nearest to at: in, akimbo, ursus, during, sponsors, from, on, bogies,
# Nearest to state: aristocratic, wished, discard, dasyprocta, operatorname, modem, capacity, language,
# Nearest to and: or, but, including, in, ursus, operatorname, circ, pulau,
# Nearest to one: two, four, five, six, operatorname, ursus, eight, three,
# Nearest to been: be, was, were, become, by, kapoor, dedicating, dictatorships,
# Nearest to or: and, ursus, phi, but, stitch, circ, two, zero,
# Nearest to used: designed, bryozoans, able, known, dddddd, seen, agouti, airtight,
# Nearest to his: their, its, her, the, s, agouti, dean, dasyprocta,
# Nearest to united: owner, dasyprocta, akimbo, agouti, seven, usury, ingesting, operatorname,
# Nearest to as: wct, coke, when, and, pulau, primigenius, ursus, by,
# Nearest to history: operatorname, agouti, roshan, dasyprocta, footballer, majority, prozac, ursus,
# Average loss at step  62000 :  5.00578854692
# Average loss at step  64000 :  4.8365229851
# Average loss at step  66000 :  4.59291762877
# Average loss at step  68000 :  4.98309177315
# Average loss at step  70000 :  4.90994681501
# Nearest to are: were, is, have, microsite, be, was, while, millimeters,
# Nearest to of: and, circ, trinomial, pulau, for, in, cio, microcebus,
# Nearest to s: and, dinar, his, mico, circ, bio, uc, hispanic,
# Nearest to nine: eight, seven, six, five, four, zero, three, ursus,
# Nearest to by: be, was, ksc, in, dasyprocta, pulau, lnot, while,
# Nearest to at: in, akimbo, during, ursus, sponsors, bogies, from, on,
# Nearest to state: aristocratic, discard, wished, perceptual, dasyprocta, language, operatorname, punitive,
# Nearest to and: or, but, including, dinar, ursus, circ, gum, operatorname,
# Nearest to one: six, four, five, two, ursus, operatorname, eight, three,
# Nearest to been: be, was, become, were, dedicating, by, being, had,
# Nearest to or: and, but, ursus, phi, dinar, while, circ, stitch,
# Nearest to used: designed, bryozoans, known, able, dinar, dddddd, seen, agouti,
# Nearest to his: their, its, her, the, s, agouti, dasyprocta, dean,
# Nearest to united: owner, dasyprocta, usury, akimbo, agouti, seven, longfellow, ingesting,
# Nearest to as: dinar, wct, when, mitral, coke, satirical, ursus, agouti,
# Nearest to history: operatorname, agouti, roshan, dasyprocta, cebus, majority, ursus, footballer,
# Average loss at step  72000 :  4.75145700693
# Average loss at step  74000 :  4.79903120315
# Average loss at step  76000 :  4.74826484084
# Average loss at step  78000 :  4.79346772185
# Average loss at step  80000 :  4.78625003719
# Nearest to are: were, is, have, microsite, be, krantz, annihilated, while,
# Nearest to of: in, pulau, trinomial, circ, microcebus, agouti, mukherjee, nine,
# Nearest to s: dinar, mico, circ, his, hispanic, bio, uc, zero,
# Nearest to nine: eight, seven, six, five, four, zero, ursus, three,
# Nearest to by: be, was, with, while, pulau, were, hide, dasyprocta,
# Nearest to at: in, akimbo, during, ursus, from, sponsors, on, bogies,
# Nearest to state: aristocratic, wished, ime, discard, operatorname, dasyprocta, punitive, perceptual,
# Nearest to and: or, but, dinar, iit, ursus, including, thaler, operatorname,
# Nearest to one: two, six, seven, operatorname, ursus, five, dinar, four,
# Nearest to been: be, was, become, were, by, dedicating, had, being,
# Nearest to or: and, stitch, but, ursus, dinar, while, than, iit,
# Nearest to used: known, bryozoans, designed, seen, able, dinar, agouti, dddddd,
# Nearest to his: their, her, its, the, s, agouti, dean, ursus,
# Nearest to united: owner, usury, akimbo, across, aka, longfellow, dasyprocta, ingesting,
# Nearest to as: mitral, dinar, wct, when, coke, agouti, ursus, microbats,
# Nearest to history: operatorname, agouti, majority, roshan, dasyprocta, cebus, baked, ursus,
# Average loss at step  82000 :  4.76563820827
# Average loss at step  84000 :  4.74867076945
# Average loss at step  86000 :  4.75644871676
# Average loss at step  88000 :  4.75903994799
# Average loss at step  90000 :  4.73839824879
# Nearest to are: were, have, is, be, microsite, while, krantz, eight,
# Nearest to of: in, trinomial, pulau, agouti, and, nine, eight, microcebus,
# Nearest to s: and, dinar, mico, circ, his, operatorname, dasyprocta, gum,
# Nearest to nine: eight, seven, six, five, four, zero, ursus, three,
# Nearest to by: was, be, with, while, pulau, were, as, dasyprocta,
# Nearest to at: in, during, akimbo, ursus, from, six, sponsors, but,
# Nearest to state: aristocratic, operatorname, ime, wished, punitive, dasyprocta, discard, perceptual,
# Nearest to and: or, but, dinar, including, while, ursus, circ, iit,
# Nearest to one: two, four, six, seven, three, five, eight, operatorname,
# Nearest to been: be, become, was, were, being, by, dedicating, had,
# Nearest to or: and, but, stitch, six, chymotrypsin, than, eight, ursus,
# Nearest to used: known, designed, bryozoans, able, seen, dinar, considered, agouti,
# Nearest to his: their, her, its, the, s, agouti, dean, ursus,
# Nearest to united: owner, usury, akimbo, dasyprocta, longfellow, aka, across, agouti,
# Nearest to as: dinar, wct, mitral, when, ursus, microsite, satirical, ssbn,
# Nearest to history: operatorname, agouti, roshan, majority, dasyprocta, cebus, ursus, baked,
# Average loss at step  92000 :  4.67085901988
# Average loss at step  94000 :  4.72503319013
# Average loss at step  96000 :  4.67617328775
# Average loss at step  98000 :  4.59730047941
# Average loss at step  100000 :  4.69317427194
# Nearest to are: were, have, is, be, krantz, while, microsite, do,
# Nearest to of: trinomial, in, constituci, pulau, eight, cio, circ, amalthea,
# Nearest to s: dinar, his, circ, mico, operatorname, and, dasyprocta, four,
# Nearest to nine: eight, seven, six, five, zero, four, three, ursus,
# Nearest to by: be, was, with, as, dasyprocta, lnot, ksc, while,
# Nearest to at: in, during, ursus, akimbo, after, from, bogies, on,
# Nearest to state: aristocratic, ime, operatorname, wished, punitive, dasyprocta, michelob, agouti,
# Nearest to and: or, but, constituci, including, dinar, iit, ursus, while,
# Nearest to one: two, seven, six, five, operatorname, eight, ursus, three,
# Nearest to been: be, become, was, were, being, invariable, dedicating, by,
# Nearest to or: and, but, while, stitch, four, constituci, chymotrypsin, dinar,
# Nearest to used: known, designed, considered, seen, able, bryozoans, dinar, agouti,
# Nearest to his: their, her, its, the, s, stenella, agouti, dean,
# Nearest to united: owner, usury, longfellow, akimbo, aka, across, dasyprocta, exam,
# Nearest to as: dinar, mitral, wct, when, agouti, satirical, primigenius, ursus,
# Nearest to history: operatorname, agouti, roshan, dasyprocta, cebus, majority, baked, ursus,

# %%
# Step 6: Visualize the embeddings.

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(40, 40))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)


from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
#import sklearn as sklearn

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels)

# %%
len(final_embeddings)
# Out:
# 50000

# %%
len(labels)
# Out:
# 500
